# %%
import numpy as np
import voronoi_interpolation as vi

# %%
input_np = vi.load_png_as_numpy("input.png")
print(f"type(input_np) = {type(input_np)}, input_np.shape = {input_np.shape}")
# Out:
# type(input_np) = <class 'numpy.ndarray'>, input_np.shape = (834, 892, 3)

# %%
sites = vi.random_sites(input_np.shape, 3000)
sites.shape
# Out:
# (3000, 2)

# %%
# %%time
output_np = vi.voronoi_interpolation(input_np, sites)
# Out:
# CPU times: user 616 ms, sys: 1.81 ms, total: 618 ms
# Wall time: 616 ms

# %%
vi.display_side_by_side(input_np, output_np)

# %%
vi.save_numpy_to_png(output_np, output_filename="output.png")

# %%
vi.display_image(output_np)

# %%
help(vi)
# Out:
# Help on package voronoi_interpolation:
#
# NAME
#     voronoi_interpolation
#
# PACKAGE CONTENTS
#     _voronoi_interpolation
#
# FUNCTIONS
#     display_image(image_np, image_title='Image')
#
#     display_side_by_side(left_np, right_np, left_title='Input Image', right_title='Output Image')
#
#     load_png_as_numpy(input_filename='input.png')
#
#     random_sites(shape, N)
#
#     save_numpy_to_png(array, output_filename='output.png')
#
# DATA
#     voronoi_interpolation = <nanobind.nb_func object>
#         voronoi_interpolation(input_image: numpy.ndarray[dtype=uint8, shape=(*, *, 3), order='C'], sites: numpy.ndarray[dtype=uint16, shape=(*, 2), order='C']) -> numpy.ndarray[dtype=uint8, shape=(*, *, 3), order='C']
#
#         Perform Voronoi interpolation on an input image and return the output image with triangle interpolation.
#
#         Parameters:
#         input_image (ndarray): An input color image as a 3D ndarray with shape (height, width, 3) and uint8 dtype.
# ...
